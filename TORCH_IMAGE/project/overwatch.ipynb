# %%
import cv2
import os

# 비디오 파일 경로 설정
video_path = '../videos/y2mate.com - Overwatch  All DVa Skins with All Highlight Intros_1080pFHR.mp4'  # 처리할 MP4 파일 경로
output_dir = 'output_images'  # 프레임을 저장할 디렉토리

# 저장할 디렉토리가 존재하지 않으면 생성
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 비디오 파일 열기
cap = cv2.VideoCapture(video_path)

frame_count = 0
save_interval = 10  # 10 프레임마다 저장

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # 10프레임마다 이미지 파일로 저장
    if frame_count % save_interval == 0:
        frame_filename = os.path.join(output_dir, f'frame_{frame_count:04d}.jpg')
        cv2.imwrite(frame_filename, frame)
        print(f'Frame {frame_count} saved at {frame_filename}')
    
    frame_count += 1

# 비디오 파일 해제
cap.release()
cv2.destroyAllWindows()

print("All frames extracted and saved.")
# Out:
# Frame 0 saved at output_images\frame_0000.jpg
# Frame 10 saved at output_images\frame_0010.jpg
# Frame 20 saved at output_images\frame_0020.jpg
# Frame 30 saved at output_images\frame_0030.jpg
# Frame 40 saved at output_images\frame_0040.jpg
# Frame 50 saved at output_images\frame_0050.jpg
# Frame 60 saved at output_images\frame_0060.jpg
# Frame 70 saved at output_images\frame_0070.jpg
# Frame 80 saved at output_images\frame_0080.jpg
# Frame 90 saved at output_images\frame_0090.jpg
# Frame 100 saved at output_images\frame_0100.jpg
# Frame 110 saved at output_images\frame_0110.jpg
# Frame 120 saved at output_images\frame_0120.jpg
# Frame 130 saved at output_images\frame_0130.jpg
# Frame 140 saved at output_images\frame_0140.jpg
# Frame 150 saved at output_images\frame_0150.jpg
# Frame 160 saved at output_images\frame_0160.jpg
# Frame 170 saved at output_images\frame_0170.jpg
# Frame 180 saved at output_images\frame_0180.jpg
# Frame 190 saved at output_images\frame_0190.jpg
# ...
