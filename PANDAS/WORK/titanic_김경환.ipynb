# %%
import pandas as pd
fileName='titanic.csv'
titanicDF=pd.read_csv(fileName)
#titanicDF.info()
titanicDF
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# survived -> adult_male -> embarked & alon

# %%
BoolDF=titanicDF[(titanicDF['adult_male']==True)&(titanicDF['survived']==0)]

# %%
BoolDF[['embark_town','alone']]
# Out:
#      embark_town  alone
# 0    Southampton  False
# 4    Southampton   True
# 5     Queenstown   True
# 6    Southampton   True
# 12   Southampton   True
# ..           ...    ...
# 881  Southampton   True
# 883  Southampton   True
# 884  Southampton   True
# 886  Southampton   True
# 890   Queenstown   True
#
# [449 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
titanicDF['sex'].isna().sum()
# Out:
# 0

# %%
serviveM=titanicDF[(titanicDF['survived']==True)&(titanicDF['sex']=='male')]
serviveF=titanicDF[(titanicDF['survived']==True)&(titanicDF['sex']=='female')]

# %%
serviveMS=serviveM['sex'].count()

# %%
serviveFS=serviveF['sex'].count()

# %%
plt.bar(['male','female'],[(serviveMS),(serviveFS)],)
# Out:
# <BarContainer object of 2 artists>
