# %% [markdown]
# #### 한국어 형태소 분석기 SpaCy
# - 빠른 속도와 정확도가 높은 형태소 분석기
# - 설치 2단계
#     * 형태소 분석기 설치
#     * 언어별 모델 설치

# %%
import spacy

# %%
LANG_MODEL='ko_core_news_lg'

# %%
nlp=spacy.load(LANG_MODEL)

# %%
text='아름답지만 다소 복잡하기도한 한국어는 전세계에서 13번째로 많이 사용되는 언어입니다. 복잡미묘한 한국어 텍스트에서 유용한 특성을 추출하기 위해 그 동안 한국어 형태소 분석기 개발되기도 했습니다.'
doc=nlp(text)
for token in doc:
    # 표제어, 단어 품사, 자세한 품사, 불용여부
    print(f'{token.text:6}  {token.lemma_:6}  {token.pos_:6}  {token.tag_:6}  {token.is_stop}')
# Out:
# 아름답지만   아름답+지+만  SCONJ   paa+ecs  False
# 다소      다소      NOUN    ncn     False
# 복잡하기도한  복잡하기+도+한  VERB    ncps+xsm+etm  False
# 한국어는    한국어+는   NOUN    ncn+jxt  False
# 전세계에서   전세계+에서  ADV     ncn+jca  False
# 13번째로   13+번+째로  ADV     nno+nbu+jca  False
# 많이      많이      ADV     mag     False
# 사용되는    사용+되+는  VERB    ncpa+xsv+etm  False
# 언어입니다   언어+이+ㅂ니다  VERB    ncn+jp+ef  False
# .       .       PUNCT   sf      False
# 복잡미묘한   복잡미묘+하+ㄴ  VERB    ncps+xsm+etm  False
# 한국어     한국어     NOUN    ncn     False
# 텍스트에서   텍스트+에서  ADV     ncn+jca  False
# 유용한     유용+하+ㄴ  VERB    ncps+xsm+etm  False
# 특성을     특성+을    NOUN    ncn+jco  False
# 추출하기    추출+하+기  VERB    ncpa+xsv+etn  False
# 위해      위하+어    SCONJ   pvg+ecs  False
# 그       그       DET     mmd     True
# 동안      동안      NOUN    ncn     False
# 한국어     한국어     NOUN    nq      False
# 형태소     형태소     NOUN    ncn     False
# 분석기     분석기     NOUN    ncn     False
# 개발되기도   개발+되+기+도  ADV     ncpa+xsv+etn+jxc  False
# 했습니다    하+었+습니다  AUX     px+ep+ef  False
# .       .       PUNCT   sf      False

# %%
my_token=[]
for token in doc:
    if not token.is_punct:
        my_token.append(token)

# %%
my_token
# Out:
# [아름답지만,
#  다소,
#  복잡하기도한,
#  한국어는,
#  전세계에서,
#  13번째로,
#  많이,
#  사용되는,
#  언어입니다,
#  복잡미묘한,
#  한국어,
#  텍스트에서,
#  유용한,
#  특성을,
#  추출하기,
#  위해,
#  그,
#  동안,
#  한국어,
#  형태소,
#  분석기,
#  개발되기도,
#  했습니다]

# %%
from IPython.display import SVG
SVG(spacy.displacy.render(doc))
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ko" id="bbdc4f930be04845a8ea61a0470a2c92-0" class="displacy" width="4075" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">아름답지만</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">다소</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">복잡하기도한</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">한국어는</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">전세계에서</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">13번째로</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">많이</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">사용되는</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">언어입니다.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">복잡미묘한</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">한국어</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">텍스트에서</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">유용한</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">특성을</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">추출하기</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">위해</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">그</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">동안</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">한국어</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">형태소</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">분석기</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">개발되기도</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">했습니다.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">AUX</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bbdc4f930be04845a8ea61a0470a2c92-0-0" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bbdc4f930be04845a8ea61a0470a2c92-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bbdc4f930be04845a8ea61a0470a2c92-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bbdc4f930be04845a8ea61a0470a2c92-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bbdc4f930be04845a8ea61a0470a2c92-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bbdc4f930be04845a8ea61a0470a2c92-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bbdc4f930be04845a8ea61a0470a2c92-0-3" stroke-width="2px" d="M595,352.0 C595,2.0 1450.0,2.0 1450.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-si
