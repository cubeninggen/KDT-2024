# %%
import pandas as pd
import os
from collections import Counter
TRAIN_PATH='../data/lang/train/'
TEST_PATH='../data/lang/test/'
TRAIN_CSV='../data/lang_train.csv'
TEST_CSV='../data/lang_test.csv'

# %%
if not os.path.exists(TRAIN_CSV):
    print(f'{TRAIN_CSV}file dose not exists')
else:
    with open(TRAIN_CSV,mode='r')as f:
        alldata=f.read()
        print(f'[File data]{alldata}')
# Out:
# ../data/lang_train.csvfile dose not exists

# %%
#폴더 내부파일 
files=os.listdir(TRAIN_PATH)
for i in files:
    print(i,TRAIN_PATH+i,os.path.exists(TRAIN_PATH+i))
    label=i[:2]
    print(f'[Label] => {label}')
    with open(TRAIN_PATH+i,mode='r')as f:
        alldata=f.read()


    # 대소문자 통일
    alldata=alldata.lower()
    # 알파벳이 아닌 문자제거
    alldata=alldata.replace('\n','')
    print(f'alldata => {len(alldata)}')

    for j in alldata:
        if ord('a')> ord(j) or ord(j) > ord('z'):
            alldata=alldata.replace(j,'')
    print(f'alldata => {len(alldata)}')

    with open(TRAIN_CSV,mode='a')as f:
        cc=dict(Counter(alldata))
        f.write(label+',')
        f.write(','.join([str(value) for value in cc.values()])+'\n')
    
    s_alldata=Counter(alldata)
    print(s_alldata)
    # temp={}
    # for j in alldata:
    #     if j in temp:
    #         temp[j]=temp[j]+1
    #     else:
    #         temp[j]=1
    # print(temp)
# Out:
# en-1.txt ../data/lang/train/en-1.txt True
# [Label] => en
# alldata => 5358
# alldata => 4595
# Counter({'e': 484, 'o': 412, 't': 370, 'r': 357, 'n': 356, 'a': 349, 'i': 340, 's': 282, 'l': 247, 'd': 212, 'c': 210, 'h': 201, 'm': 121, 'u': 119, 'y': 92, 'g': 88, 'p': 76, 'f': 72, 'w': 65, 'b': 59, 'v': 45, 'k': 25, 'j': 8, 'x': 3, 'z': 2})
# en-2.txt ../data/lang/train/en-2.txt True
# [Label] => en
# alldata => 10782
# alldata => 8387
# Counter({'e': 1149, 'r': 756, 'a': 706, 't': 652, 'i': 632, 's': 601, 'o': 577, 'n': 449, 'l': 355, 'd': 326, 'g': 262, 'u': 257, 'c': 255, 'h': 230, 'm': 203, 'p': 170, 'b': 167, 'f': 146, 'w': 117, 'v': 115, 'y': 90, 'k': 82, 'q': 46, 'j': 22, 'x': 17, 'z': 5})
# en-3.txt ../data/lang/train/en-3.txt True
# [Label] => en
# alldata => 4397
# alldata => 3615
# Counter({'e': 434, 'i': 342, 's': 318, 't': 293, 'o': 277, 'n': 273, 'a': 259, 'l': 206, 'r': 195, 'c': 165, 'd': 118, 'u': 105, 'g': 91, 'h': 85, 'm': 81, 'p': 75, 'v': 68, 'y': 65, 'f': 53, 'b': 44, 'w': 43, 'j': 9, 'k': 6, 'q': 6, 'x': 2, 'z': 2})
# en-4.txt ../data/lang/train/en-4.txt True
# [Label] => en
# alldata => 6815
# alldata => 5304
# Counter({'e': 642, 't': 497, 'o': 465, 's': 389, 'a': 383, 'i': 346, 'r': 314, 'h': 313, 'n': 311, 'l': 238, 'd': 210, 'c': 159, 'b': 147, 'u': 129, 'g': 125, 'm': 114, 'w': 104, 'y': 93, 'f': 89, 'p': 89, 'k': 69, 'x': 32, 'v': 27, 'z': 9, 'j': 8, 'q': 2})
# en-5.txt ../data/lang/train/en-5.txt True
# [Label] => en
# alldata => 6146
# alldata => 4566
# Counter({'e': 645, 't': 436, 'a': 337, 'r': 331, 'o': 302, 'i': 297, 'n': 284, 's': 272, 'h': 260, 'l': 181, 'd': 181, 'c': 142, 'm': 132, 'u': 114, 'w': 109, 'b': 93, 'g': 93, 'f': 93, 'p': 86, 'y': 68, 'v': 49, 'k': 27, 'j': 15, 'x': 14, 'z': 3, 'q': 2})
# fr-10.txt ../data/lang/train/fr-10.txt True
# [Label] => fr
# alldata => 21300
# alldata => 15596
# Counter({'e': 2347, 'a': 1228, 't': 1210, 'r': 1171, 'n': 1126, 's': 1117, 'l': 1096, 'i': 1082, 'u': 834, 'd': 831, 'o': 767, 'c': 581, 'm': 418, 'p': 406, 'f': 253, 'h': 242, 'v': 223, 'g': 167, 'b': 163, 'q': 92, 'k': 64, 'x': 61, 'y': 57, 'j': 36, 'z': 13, 'w': 11})
# fr-6.txt ../data/lang/train/fr-6.txt True
# [Label] => fr
# alldata => 36732
# alldata => 27749
# Counter({'e': 4155, 's': 2278, 'a': 2162, 'r': 2074, 'i': 1998, 't': 1958, 'n': 1908, 'l': 1804, 'o': 1580, 'u': 1511, 'd': 1244, 'c': 992, 'm': 873, 'p': 809, 'b': 414, 'h': 350, 'f': 327, 'g': 319, 'v': 295, 'q': 190, 'y': 148, 'w': 126, 'x': 108, 'j': 59, 'k': 54, 'z': 13})
# fr-7.txt ../data/lang/train/fr-7.txt True
# [Label] => fr
# alldata => 22105
# alldata => 16915
# Counter({'e': 2550, 's': 1325, 'r': 1301, 'n': 1290, 'a': 1230, 'i': 1208, 't': 1111, 'o': 1048, 'l': 1008, 'u': 861, 'd': 761, 'm': 711, 'c': 599, 'p': 532, 'b': 221, 'v': 215, 'h': 195, 'g': 179, 'f': 178, 'q': 112, 'x': 84, 'y': 82, 'j': 51, 'w': 44, 'k': 17, 'z': 2})
# fr-8.txt ../data/lang/train/fr-8.txt True
# [Label] => fr
# alldata => 11142
# alldata => 8058
# Counter({'e': 1266, 'i': 690, 'r': 661, 'n': 596, 'a': 585, 's': 536, 'l': 500, 't': 492, 'o': 453, 'd': 412, 'u': 344, 'c': 321, 'm': 234, 'p': 189, 'b': 127, 'v': 122, 'h': 116, 'g': 109, 'f': 105, 'q': 47, 'x': 41, 'y': 40, 'j': 35, 'z': 16, 'k': 15, 'w': 6})
# fr-9.txt ../data/lang/train/fr-9.txt True
# [Label] => fr
# alldata => 7016
# alldata => 5130
# Counter({'e': 735, 'i': 461, 'n': 410, 'a': 405, 'r': 399, 's': 371, 't': 325, 'o': 306, 'l': 295, 'd': 266, 'u': 225, 'c': 181, 'm': 127, 'p': 120, 'g': 103, 'h': 100, 'v': 72, 'f': 62, 'b': 59, 'y': 27, 'q': 24, 'j': 20, 'x': 17, 'k': 12, 'z': 6, 'w': 2})
# id-11.txt ../data/lang/train/id-11.txt True
# [Label] => id
# alldata => 2634
# alldata => 2007
# Counter({'a': 253, 'i': 210, 'e': 194, 'n': 173, 'r': 154, 's': 139, 'g': 120, 'l': 97, 't': 94, 'u': 85, 'o': 75, 'd': 69, 'b': 65, 'm': 59, 'k': 50, 'p': 50, 'c': 29, 'h': 28, 'y': 19, 'w': 13, 'f': 9, 'j': 8, 'v': 8, 'z': 3, 'x': 3})
# id-12.txt ../data/lang/train/id-12.txt True
# [Label] => id
# alldata => 9938
# alldata => 7936
# Counter({'a': 1171, 'i': 796, 'e': 741, 'n': 672, 's': 646, 't': 403, 'r': 370, 'u': 322, 'd': 313, 'm': 305, 'k': 301, 'l': 295, 'o': 282, 'p': 276, 'g': 269, 'b': 196, 'h': 147, 'y': 108, 'f': 88, 'c': 73, 'v': 64, 'j': 42, 'w': 40, 'x': 11, 'z': 5})
# id-13.txt ../data/lang/train/id-13.txt True
# [Label] => id
# alldata => 30287
# alldata => 25451
# Counter({'a': 4514, 'n': 2528, 'i': 2218, 'e': 2129, 'r': 1325, 't': 1269, 'g': 1262, 'u': 1235, 's': 1212, 'm': 1067, 'k': 1003, 'd': 986, 'l': 904, 'o': 787, 'p': 765, 'b': 594, 'h': 475, 'y': 371, 'f': 323, 'j': 188, 'c': 140, 'w': 104, 'v': 40, 'z': 6, 'x': 6})
# id-14.txt ../data/lang/train/id-14.txt True
# [Label] => id
# alldata => 17324
# alldata => 14905
# Counter({'a': 2522, 'i': 1451, 'n': 1326, 'e': 1039, 'o': 863, 's': 811, 'r': 746, 't': 742, 'l': 723, 'u': 695, 'g': 672, 'm': 647, 'k': 611, 'd': 483, 'p': 442, 'b': 377, 'h': 224, 'y': 175, 'f': 118, 'j': 99, 'c': 68, 'v': 33, 'w': 27, 'z': 8, 'x': 3})
# id-15.txt ../data/lang/train/id-15.txt True
# [Label] => id
# alldata => 78297
# alldata => 61604
# Counter({'a': 11092, 'n': 6155, 'i': 5464, 'e': 5149, 'r': 3504, 's': 3350, 't': 3093, 'd': 2840, 'u': 2665, 'k': 2213, 'l': 2198, 'o': 2145, 'g': 2102, 'm': 2093, 'p': 1831, 'b': 1581, 'h': 1283, 'y': 796, 'j': 558, 'c': 508, 'w': 384, 'f': 315, 'v': 185, 'z': 70, 'x': 19, 'q': 11})
# tl-16.txt ../data/lang/train/tl-16.txt True
# [Label] => tl
# alldata => 34630
# alldata => 27338
# Counter({'a': 6098, 'n': 3478, 'g': 2633, 'i': 2383, 't': 1491, 'l': 1390, 's': 1341, 'o': 1223, 'p': 917, 'm': 826, 'u': 752, 'k': 739, 'b': 672, 'e': 662, 'y': 550, 'h': 514, 'r': 483, 'd': 360, 'w': 339, 'c': 222, 'f': 96, 'v': 67, 'j': 35, 'z': 29, 'q': 24, 'x': 14})
# tl-17.txt ../data/lang/train/tl-17.txt True
# [Label] => tl
# alldata => 40515
# alldata => 32871
# Counter({'a': 7231, 'n': 4250, 'g': 2955, 'i': 2799, 's': 1779, 'o': 1626, 'l': 1523, 't': 1475, 'm': 1420, 'k': 1152, 'u': 1074, 'p': 948, 'y': 926, 'r': 762, 'e': 758, 'b': 589, 'h': 555, 'd': 460, 'w': 299, 'c': 164, 'f': 59, 'j': 23, 'v': 21, 'x': 10, 'q': 8, 'z': 5})
# tl-18.txt ../data/lang/train/tl-18.txt True
# [Label] => tl
# alldata => 22366
# alldata => 17848
# Counter({'a': 4100, 'n': 2414, 'g': 1632, 'i': 1256, 't': 1064, 'l': 880, 's': 845, 'o': 764, 'm': 628, 'u': 621, 'p': 559, 'k': 557, 'e': 532, 'r': 480, 'b': 376, 'y': 352, 'w': 255, 'd': 228, 'h': 201, 'c': 45, 'j': 32, 'v': 19, 'f': 5, 'z': 1, 'q': 1, 'x': 1})
# tl-19.txt ../data/lang/train/tl-19.txt True
# [Label] => tl
# alldata => 15555
# alldata => 11568
# Counter({'a': 2054, 'n': 1307, 'i': 862, 'g': 774, 'e': 751, 's': 682, 'o': 648, 't': 634, 'r': 531, 'l': 491, 'm': 432, 'p': 337, 'u': 322, 'y': 270, 'b': 264, 'd': 252, 'k': 238, 'h': 220, 'c': 220, 'w': 95, 'v': 59, 'f': 57, 'z': 31, 'j': 22, 'x': 10, 'q': 5})
# tl-20.txt ../data/lang/train/tl-20.txt True
# [Label] => tl
# alldata => 9000
# alldata => 7259
# Counter({'a': 1469, 'n': 834, 'i': 548, 'o': 491, 's': 472, 'e': 466, 'l': 367, 't': 335, 'r': 286, 'd': 269, 'y': 246, 'g': 240, 'p': 224, 'u': 202, 'm': 173, 'b': 165, 'c': 142, 'k': 107, 'h': 49, 'w': 42, 'f': 42, 'v': 35, 'z': 22, 'j': 17, 'q': 13, 'x': 3})

# %%
def make_csv(dir_path,file_path):
    files=os.listdir(dir_path)
    for i in files:
        print(i,dir_path+i,os.path.exists(dir_path+i))
        label=i[:2]
        print(f'[Label] => {label}')
        with open(dir_path+i,mode='r')as f:
            alldata=f.read()


        # 대소문자 통일
        alldata=alldata.lower()
        # 알파벳이 아닌 문자제거
        alldata=alldata.replace('\n','')
        print(f'alldata => {len(alldata)}')

        for j in alldata:
            if ord('a')> ord(j) or ord(j) > ord('z'):
                alldata=alldata.replace(j,'')
        print(f'alldata => {len(alldata)}')

        with open(file_path,mode='a')as f:
            # cc=dict(Counter(alldata))
            a_z=[]
            for _ in range(97,123):
                a_z.append(str((alldata.count(chr(_)))/len(alldata)))
            f.write(label+',')
            f.write(','.join(a_z)+'\n')
        
        s_alldata=Counter(alldata)
        print(s_alldata)

make_csv(TRAIN_PATH,TRAIN_CSV)
make_csv(TEST_PATH,TEST_CSV)
# Out:
# en-1.txt ../data/lang/train/en-1.txt True
# [Label] => en
# alldata => 5358
# alldata => 4595
# Counter({'e': 484, 'o': 412, 't': 370, 'r': 357, 'n': 356, 'a': 349, 'i': 340, 's': 282, 'l': 247, 'd': 212, 'c': 210, 'h': 201, 'm': 121, 'u': 119, 'y': 92, 'g': 88, 'p': 76, 'f': 72, 'w': 65, 'b': 59, 'v': 45, 'k': 25, 'j': 8, 'x': 3, 'z': 2})
# en-2.txt ../data/lang/train/en-2.txt True
# [Label] => en
# alldata => 10782
# alldata => 8387
# Counter({'e': 1149, 'r': 756, 'a': 706, 't': 652, 'i': 632, 's': 601, 'o': 577, 'n': 449, 'l': 355, 'd': 326, 'g': 262, 'u': 257, 'c': 255, 'h': 230, 'm': 203, 'p': 170, 'b': 167, 'f': 146, 'w': 117, 'v': 115, 'y': 90, 'k': 82, 'q': 46, 'j': 22, 'x': 17, 'z': 5})
# en-3.txt ../data/lang/train/en-3.txt True
# [Label] => en
# alldata => 4397
# alldata => 3615
# Counter({'e': 434, 'i': 342, 's': 318, 't': 293, 'o': 277, 'n': 273, 'a': 259, 'l': 206, 'r': 195, 'c': 165, 'd': 118, 'u': 105, 'g': 91, 'h': 85, 'm': 81, 'p': 75, 'v': 68, 'y': 65, 'f': 53, 'b': 44, 'w': 43, 'j': 9, 'k': 6, 'q': 6, 'x': 2, 'z': 2})
# en-4.txt ../data/lang/train/en-4.txt True
# [Label] => en
# alldata => 6815
# alldata => 5304
# Counter({'e': 642, 't': 497, 'o': 465, 's': 389, 'a': 383, 'i': 346, 'r': 314, 'h': 313, 'n': 311, 'l': 238, 'd': 210, 'c': 159, 'b': 147, 'u': 129, 'g': 125, 'm': 114, 'w': 104, 'y': 93, 'f': 89, 'p': 89, 'k': 69, 'x': 32, 'v': 27, 'z': 9, 'j': 8, 'q': 2})
# en-5.txt ../data/lang/train/en-5.txt True
# [Label] => en
# alldata => 6146
# alldata => 4566
# Counter({'e': 645, 't': 436, 'a': 337, 'r': 331, 'o': 302, 'i': 297, 'n': 284, 's': 272, 'h': 260, 'l': 181, 'd': 181, 'c': 142, 'm': 132, 'u': 114, 'w': 109, 'b': 93, 'g': 93, 'f': 93, 'p': 86, 'y': 68, 'v': 49, 'k': 27, 'j': 15, 'x': 14, 'z': 3, 'q': 2})
# fr-10.txt ../data/lang/train/fr-10.txt True
# [Label] => fr
# alldata => 21300
# alldata => 15596
# Counter({'e': 2347, 'a': 1228, 't': 1210, 'r': 1171, 'n': 1126, 's': 1117, 'l': 1096, 'i': 1082, 'u': 834, 'd': 831, 'o': 767, 'c': 581, 'm': 418, 'p': 406, 'f': 253, 'h': 242, 'v': 223, 'g': 167, 'b': 163, 'q': 92, 'k': 64, 'x': 61, 'y': 57, 'j': 36, 'z': 13, 'w': 11})
# fr-6.txt ../data/lang/train/fr-6.txt True
# [Label] => fr
# alldata => 36732
# alldata => 27749
# Counter({'e': 4155, 's': 2278, 'a': 2162, 'r': 2074, 'i': 1998, 't': 1958, 'n': 1908, 'l': 1804, 'o': 1580, 'u': 1511, 'd': 1244, 'c': 992, 'm': 873, 'p': 809, 'b': 414, 'h': 350, 'f': 327, 'g': 319, 'v': 295, 'q': 190, 'y': 148, 'w': 126, 'x': 108, 'j': 59, 'k': 54, 'z': 13})
# fr-7.txt ../data/lang/train/fr-7.txt True
# [Label] => fr
# alldata => 22105
# alldata => 16915
# Counter({'e': 2550, 's': 1325, 'r': 1301, 'n': 1290, 'a': 1230, 'i': 1208, 't': 1111, 'o': 1048, 'l': 1008, 'u': 861, 'd': 761, 'm': 711, 'c': 599, 'p': 532, 'b': 221, 'v': 215, 'h': 195, 'g': 179, 'f': 178, 'q': 112, 'x': 84, 'y': 82, 'j': 51, 'w': 44, 'k': 17, 'z': 2})
# fr-8.txt ../data/lang/train/fr-8.txt True
# [Label] => fr
# alldata => 11142
# alldata => 8058
# Counter({'e': 1266, 'i': 690, 'r': 661, 'n': 596, 'a': 585, 's': 536, 'l': 500, 't': 492, 'o': 453, 'd': 412, 'u': 344, 'c': 321, 'm': 234, 'p': 189, 'b': 127, 'v': 122, 'h': 116, 'g': 109, 'f': 105, 'q': 47, 'x': 41, 'y': 40, 'j': 35, 'z': 16, 'k': 15, 'w': 6})
# fr-9.txt ../data/lang/train/fr-9.txt True
# [Label] => fr
# alldata => 7016
# alldata => 5130
# Counter({'e': 735, 'i': 461, 'n': 410, 'a': 405, 'r': 399, 's': 371, 't': 325, 'o': 306, 'l': 295, 'd': 266, 'u': 225, 'c': 181, 'm': 127, 'p': 120, 'g': 103, 'h': 100, 'v': 72, 'f': 62, 'b': 59, 'y': 27, 'q': 24, 'j': 20, 'x': 17, 'k': 12, 'z': 6, 'w': 2})
# id-11.txt ../data/lang/train/id-11.txt True
# [Label] => id
# alldata => 2634
# alldata => 2007
# Counter({'a': 253, 'i': 210, 'e': 194, 'n': 173, 'r': 154, 's': 139, 'g': 120, 'l': 97, 't': 94, 'u': 85, 'o': 75, 'd': 69, 'b': 65, 'm': 59, 'k': 50, 'p': 50, 'c': 29, 'h': 28, 'y': 19, 'w': 13, 'f': 9, 'j': 8, 'v': 8, 'z': 3, 'x': 3})
# id-12.txt ../data/lang/train/id-12.txt True
# [Label] => id
# alldata => 9938
# alldata => 7936
# Counter({'a': 1171, 'i': 796, 'e': 741, 'n': 672, 's': 646, 't': 403, 'r': 370, 'u': 322, 'd': 313, 'm': 305, 'k': 301, 'l': 295, 'o': 282, 'p': 276, 'g': 269, 'b': 196, 'h': 147, 'y': 108, 'f': 88, 'c': 73, 'v': 64, 'j': 42, 'w': 40, 'x': 11, 'z': 5})
# id-13.txt ../data/lang/train/id-13.txt True
# [Label] => id
# alldata => 30287
# alldata => 25451
# Counter({'a': 4514, 'n': 2528, 'i': 2218, 'e': 2129, 'r': 1325, 't': 1269, 'g': 1262, 'u': 1235, 's': 1212, 'm': 1067, 'k': 1003, 'd': 986, 'l': 904, 'o': 787, 'p': 765, 'b': 594, 'h': 475, 'y': 371, 'f': 323, 'j': 188, 'c': 140, 'w': 104, 'v': 40, 'z': 6, 'x': 6})
# id-14.txt ../data/lang/train/id-14.txt True
# [Label] => id
# alldata => 17324
# alldata => 14905
# Counter({'a': 2522, 'i': 1451, 'n': 1326, 'e': 1039, 'o': 863, 's': 811, 'r': 746, 't': 742, 'l': 723, 'u': 695, 'g': 672, 'm': 647, 'k': 611, 'd': 483, 'p': 442, 'b': 377, 'h': 224, 'y': 175, 'f': 118, 'j': 99, 'c': 68, 'v': 33, 'w': 27, 'z': 8, 'x': 3})
# id-15.txt ../data/lang/train/id-15.txt True
# [Label] => id
# alldata => 78297
# alldata => 61604
# Counter({'a': 11092, 'n': 6155, 'i': 5464, 'e': 5149, 'r': 3504, 's': 3350, 't': 3093, 'd': 2840, 'u': 2665, 'k': 2213, 'l': 2198, 'o': 2145, 'g': 2102, 'm': 2093, 'p': 1831, 'b': 1581, 'h': 1283, 'y': 796, 'j': 558, 'c': 508, 'w': 384, 'f': 315, 'v': 185, 'z': 70, 'x': 19, 'q': 11})
# tl-16.txt ../data/lang/train/tl-16.txt True
# [Label] => tl
# alldata => 34630
# alldata => 27338
# Counter({'a': 6098, 'n': 3478, 'g': 2633, 'i': 2383, 't': 1491, 'l': 1390, 's': 1341, 'o': 1223, 'p': 917, 'm': 826, 'u': 752, 'k': 739, 'b': 672, 'e': 662, 'y': 550, 'h': 514, 'r': 483, 'd': 360, 'w': 339, 'c': 222, 'f': 96, 'v': 67, 'j': 35, 'z': 29, 'q': 24, 'x': 14})
# tl-17.txt ../data/lang/train/tl-17.txt True
# [Label] => tl
# alldata => 40515
# alldata => 32871
# Counter({'a': 7231, 'n': 4250, 'g': 2955, 'i': 2799, 's': 1779, 'o': 1626, 'l': 1523, 't': 1475, 'm': 1420, 'k': 1152, 'u': 1074, 'p': 948, 'y': 926, 'r': 762, 'e': 758, 'b': 589, 'h': 555, 'd': 460, 'w': 299, 'c': 164, 'f': 59, 'j': 23, 'v': 21, 'x': 10, 'q': 8, 'z': 5})
# tl-18.txt ../data/lang/train/tl-18.txt True
# [Label] => tl
# alldata => 22366
# alldata => 17848
# Counter({'a': 4100, 'n': 2414, 'g': 1632, 'i': 1256, 't': 1064, 'l': 880, 's': 845, 'o': 764, 'm': 628, 'u': 621, 'p': 559, 'k': 557, 'e': 532, 'r': 480, 'b': 376, 'y': 352, 'w': 255, 'd': 228, 'h': 201, 'c': 45, 'j': 32, 'v': 19, 'f': 5, 'z': 1, 'q': 1, 'x': 1})
# tl-19.txt ../data/lang/train/tl-19.txt True
# [Label] => tl
# alldata => 15555
# alldata => 11568
# Counter({'a': 2054, 'n': 1307, 'i': 862, 'g': 774, 'e': 751, 's': 682, 'o': 648, 't': 634, 'r': 531, 'l': 491, 'm': 432, 'p': 337, 'u': 322, 'y': 270, 'b': 264, 'd': 252, 'k': 238, 'h': 220, 'c': 220, 'w': 95, 'v': 59, 'f': 57, 'z': 31, 'j': 22, 'x': 10, 'q': 5})
# tl-20.txt ../data/lang/train/tl-20.txt True
# [Label] => tl
# alldata => 9000
# alldata => 7259
# Counter({'a': 1469, 'n': 834, 'i': 548, 'o': 491, 's': 472, 'e': 466, 'l': 367, 't': 335, 'r': 286, 'd': 269, 'y': 246, 'g': 240, 'p': 224, 'u': 202, 'm': 173, 'b': 165, 'c': 142, 'k': 107, 'h': 49, 'w': 42, 'f': 42, 'v': 35, 'z': 22, 'j': 17, 'q': 13, 'x': 3})
# en-1.txt ../data/lang/test/en-1.txt True
# [Label] => en
# alldata => 59001
# alldata => 45619
# Counter({'e': 5297, 'o': 3820, 's': 3629, 'i': 3509, 't': 3427, 'n': 3376, 'r': 3199, 'a': 3094, 'd': 2227, 'l': 1746, 'w': 1647, 'c': 1566, 'm': 1373, 'p': 1292, 'u': 1182, 'h': 1040, 'f': 913, 'g': 730, 'v': 674, 'b': 614, 'y': 597, 'x': 257, 'k': 251, 'j': 110, 'q': 30, 'z': 19})
# en-2.txt ../data/lang/test/en-2.txt True
# [Label] => en
# alldata => 139001
# alldata => 101952
# Counter({'e': 13240, 'a': 8185, 't': 8042, 'i': 7543, 'o': 7537, 'n': 7191, 'r': 6752, 's': 6484, 'l': 4417, 'h': 4353, 'p': 4179, 'd': 3909, 'c': 3604, 'u': 2817, 'm': 2588, 'g': 1932, 'f': 1703, 'b': 1649, 'w': 1517, 'y': 1356, 'v': 1328, 'k': 687, 'j': 455, 'x': 216, 'z': 152, 'q': 116})
# fr-3.txt ../data/lang/test/fr-3.txt True
# [Label] => fr
# alldata => 35425
# alldata => 26566
# Counter({'e': 3378, 's': 2393, 'i': 2286, 'o': 2062, 'n': 1965, 't': 1818, 'r': 1788, 'a': 1508, 'd': 1325, 'l': 1228, 'u': 1140, 'c': 952, 'p': 937, 'm': 866, 'w': 768, 'v': 368, 'f': 358, 'b': 319, 'x': 247, 'g': 229, 'h': 194, 'q': 169, 'y': 137, 'j': 74, 'k': 46, 'z': 11})
# fr-4.txt ../data/lang/test/fr-4.txt True
# [Label] => fr
# alldata => 63459
# alldata => 45301
# Counter({'e': 6313, 'i': 3601, 's': 3308, 'a': 3256, 'n': 3209, 'o': 3166, 't': 3005, 'r': 2902, 'l': 2661, 'p': 2247, 'u': 2204, 'd': 1827, 'c': 1743, 'm': 1504, 'h': 834, 'g': 697, 'v': 616, 'f': 552, 'b': 517, 'q': 312, 'x': 194, 'j': 188, 'y': 152, 'w': 131, 'k': 108, 'z': 54})
# id-5.txt ../data/lang/test/id-5.txt True
# [Label] => id
# alldata => 7930
# alldata => 6154
# Counter({'a': 642, 'i': 557, 'e': 550, 'n': 512, 's': 488, 'r': 428, 'o': 373, 't': 325, 'd': 272, 'm': 258, 'u': 227, 'l': 211, 'w': 207, 'g': 164, 'p': 160, 'k': 151, 'b': 138, 'v': 102, 'h': 96, 'c': 94, 'f': 70, 'y': 59, 'j': 33, 'x': 30, 'q': 4, 'z': 3})
# id-6.txt ../data/lang/test/id-6.txt True
# [Label] => id
# alldata => 33000
# alldata => 25641
# Counter({'a': 4224, 'n': 2304, 'e': 2263, 'i': 2104, 'r': 1375, 't': 1365, 's': 1251, 'u': 1216, 'l': 1103, 'd': 1066, 'm': 1048, 'k': 988, 'p': 932, 'g': 923, 'o': 799, 'b': 668, 'h': 644, 'y': 380, 'c': 374, 'j': 186, 'f': 159, 'v': 120, 'w': 118, 'z': 15, 'x': 12, 'q': 4})
# tl-7.txt ../data/lang/test/tl-7.txt True
# [Label] => tl
# alldata => 33673
# alldata => 26235
# Counter({'a': 4868, 'n': 3207, 'g': 2165, 'i': 2144, 's': 1540, 'o': 1525, 't': 1371, 'm': 1001, 'r': 940, 'l': 932, 'e': 868, 'p': 821, 'w': 744, 'd': 701, 'u': 627, 'k': 626, 'b': 516, 'y': 448, 'c': 377, 'h': 369, 'f': 209, 'v': 126, 'x': 89, 'z': 11, 'j': 6, 'q': 4})
# tl-8.txt ../data/lang/test/tl-8.txt True
# [Label] => tl
# alldata => 2052
# alldata => 1652
# Counter({'a': 277, 'n': 175, 'i': 116, 'o': 112, 'g': 110, 't': 102, 'e': 92, 'p': 87, 's': 87, 'r': 73, 'l': 67, 'u': 62, 'm': 59, 'd': 41, 'k': 34, 'c': 31, 'y': 30, 'b': 28, 'w': 27, 'h': 19, 'f': 15, 'v': 3, 'q': 2, 'j': 1, 'z': 1, 'x': 1})

# %%
trainDF=pd.read_csv(TRAIN_CSV,header=None)
trainDF
# Out:
#     0         1         2         3         4         5         6         7   \
# 0   en  0.075952  0.012840  0.045702  0.046137  0.105332  0.015669  0.019151
# 1   en  0.084178  0.019912  0.030404  0.038870  0.136998  0.017408  0.031239
# 2   en  0.071646  0.012172  0.045643  0.032642  0.120055  0.014661  0.025173
# 3   en  0.072210  0.027715  0.029977  0.039593  0.121041  0.016780  0.023567
# 4   en  0.073806  0.020368  0.031099  0.039641  0.141261  0.020368  0.020368
# 5   fr  0.078738  0.010451  0.037253  0.053283  0.150487  0.016222  0.010708
# 6   fr  0.077913  0.014919  0.035749  0.044830  0.149735  0.011784  0.011496
# 7   fr  0.072717  0.013065  0.035412  0.044990  0.150754  0.010523  0.010582
# 8   fr  0.072599  0.015761  0.039836  0.051129  0.157111  0.013031  0.013527
# 9   fr  0.078947  0.011501  0.035283  0.051852  0.143275  0.012086  0.020078
# 10  id  0.126059  0.032387  0.014449  0.034380  0.096662  0.004484  0.059791
# 11  id  0.147555  0.024698  0.009199  0.039441  0.093372  0.011089  0.033896
# 12  id  0.177360  0.023339  0.005501  0.038741  0.083651  0.012691  0.049585
# 13  id  0.169205  0.025294  0.004562  0.032405  0.069708  0.007917  0.045086
# 14  id  0.180053  0.025664  0.008246  0.046101  0.083582  0.005113  0.034121
# 15  tl  0.223059  0.024581  0.008121  0.013168  0.024215  0.003512  0.096313
# 16  tl  0.219981  0.017919  0.004989  0.013994  0.023060  0.001795  0.089897
# 17  tl  0.229718  0.021067  0.002521  0.012775  0.029807  0.000280  0.091439
# 18  tl  0.177559  0.022822  0.019018  0.021784  0.064920  0.004927  0.066909
# 19  tl  0.202369  0.022730  0.019562  0.037057  0.064196  0.005786  0.033062
#
#           8         9   ...        17        18        19        20        21  \
# 0   0.043743  0.073993  ...  0.000000  0.077693  0.061371  0.080522  0.025898
# 1   0.027423  0.075355  ...  0.005485  0.090140  0.071659  0.077739  0.030643
# 2   0.023513  0.094606  ...  0.001660  0.053942  0.087967  0.081051  0.029046
# 3   0.059012  0.065234  ...  0.000377  0.059201  0.073341  0.093703  0.024321
# 4   0.056943  0.065046  ...  0.000438  0.072492  0.059571  0.095488  0.024967
# 5   0.015517  0.069377  ...  0.005899  0.075083  0.071621  0.077584  0.053475
# 6   0.012613  0.072003  ...  0.006847  0.074741  0.082093  0.070561  0.054452
# 7   0.011528  0.071416  ...  0.006621  0.076914  0.078333  0.065681  0.050902
# 8   0.014396  0.085629  ...  0.005833  0.082030  0.066518  0.061057  0.042690
# 9   0.019493  0.089864  ...  0.004678  0.077778  0.072320  0.063353  0.043860
# 10  0.013951  0.104634  ...  0.000000  0.076731  0.069258  0.046836  0.042352
# 11  0.018523  0.100302  ...  0.000000  0.046623  0.081401  0.050781  0.040575
# 12  0.018663  0.087148  ...  0.000000  0.052061  0.047621  0.049861  0.048525
# 13  0.015029  0.097350  ...  0.000000  0.050050  0.054411  0.049782  0.046629
# 14  0.020827  0.088696  ...  0.000179  0.056879  0.054380  0.050208  0.043260
# 15  0.018802  0.087168  ...  0.000878  0.017668  0.049053  0.054539  0.027507
# 16  0.016884  0.085151  ...  0.000243  0.023182  0.054121  0.044872  0.032673
# 17  0.011262  0.070372  ...  0.000056  0.026894  0.047344  0.059615  0.034794
# 18  0.019018  0.074516  ...  0.000432  0.045902  0.058956  0.054806  0.027835
# 19  0.006750  0.075492  ...  0.001791  0.039399  0.065023  0.046150  0.027828
#
#           22        23        24        25        26
# 0   0.009793  0.014146  0.000653  0.020022  0.000435
# 1   0.013712  0.013950  0.002027  0.010731  0.000596
# 2   0.018811  0.011895  0.000553  0.017981  0.000553
# 3   0.005090  0.019608  0.006033  0.017534  0.001697
# 4   0.010731  0.023872  0.003066  0.014893  0.000657
# 5   0.014299  0.000705  0.003911  0.003655  0.000834
# 6   0.010631  0.004541  0.003892  0.005334  0.000468
# 7   0.012711  0.002601  0.004966  0.004848  0.000118
# 8   0.015140  0.000745  0.005088  0.004964  0.001986
# 9   0.014035  0.000390  0.003314  0.005263  0.001170
# 10  0.003986  0.006477  0.001495  0.009467  0.001495
# 11  0.008065  0.005040  0.001386  0.013609  0.000630
# 12  0.001572  0.004086  0.000236  0.014577  0.000236
# 13  0.002214  0.001811  0.000201  0.011741  0.000537
# 14  0.003003  0.006233  0.000308  0.012921  0.001136
# 15  0.002451  0.012400  0.000512  0.020119  0.001061
# 16  0.000639  0.009096  0.000304  0.028171  0.000152
# 17  0.001065  0.014287  0.000056  0.019722  0.000056
# 18  0.005100  0.008212  0.000864  0.023340  0.002680
# 19  0.004822  0.005786  0.000413  0.033889  0.003031
#
# [20 rows x 27 columns]
