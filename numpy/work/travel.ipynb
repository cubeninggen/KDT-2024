# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Travel details dataset.csv")
df_copy = df.copy()
df
# Out:
#      Trip ID             Destination  ... Transportation type Transportation cost
# 0          1              London, UK  ...              Flight               600.0
# 1          2        Phuket, Thailand  ...              Flight               500.0
# 2          3         Bali, Indonesia  ...              Flight               700.0
# 3          4           New York, USA  ...              Flight              1000.0
# 4          5            Tokyo, Japan  ...               Train               200.0
# ..       ...                     ...  ...                 ...                 ...
# 132      133  Rio de Janeiro, Brazil  ...                 Car              2000.0
# 133      134       Vancouver, Canada  ...            Airplane              3000.0
# 134      135       Bangkok, Thailand  ...               Train              1000.0
# 135      136        Barcelona, Spain  ...            Airplane              2500.0
# ...

# %%
AccommodationGB=df_copy.groupby('Accommodation type')
AccommodationGB

# %%
plt.figure(figsize=(16,4), dpi=300)
sns.displot(df['Accommodation type'],kde=True, legend=True, aspect=1, color='green')
plt.xticks(rotation=90)
# Out:
# c:\Users\KDP-48\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Hotel'),
#   Text(1, 0, 'Resort'),
#   Text(2, 0, 'Villa'),
#   Text(3, 0, 'Airbnb'),
#   Text(4, 0, 'Hostel'),
#   Text(5, 0, 'Riad'),
#   Text(6, 0, 'Vacation rental'),
#   Text(7, 0, 'Guesthouse')])

# %%
sns.scatterplot(data=df, x="Duration (days)", y="Accommodation cost", hue='Accommodation type')
# Out:
# <Axes: xlabel='Duration (days)', ylabel='Accommodation cost'>
